# %%
df = spark.table("workspace.default.movies")
display(df)

# %%
df = spark.read.option("inferSchema", True).option("header", True).csv("/Volumes/workspace/default/raw_data")
display(df)

# %%
from pyspark.sql.types import *
fixed_schema = StructType([StructField('order_date', DateType(), True), 
                           StructField('country', StringType(), True), 
                           StructField('order_id', IntegerType(), True), 
                           StructField('product', StringType(), True), 
                           StructField('qty', IntegerType(), True), 
                           StructField('price', DoubleType(), True)])

df = spark.read.option("header", True).schema(fixed_schema).csv("/Volumes/workspace/default/raw_data")
display(df)

# %%
df = spark.read.option("header", True) \
        .schema(fixed_schema) \
        .option("dateFormat", "yyyy-MM-dd") \
        .csv("/Volumes/workspace/default/raw_data")
display(df)

# %%
df.write.mode("overwrite").parquet("/Volumes/workspace/default/raw_data/orders")

# %%
df_sql = spark.sql("SELECT * FROM workspace.default.movies")
display(df_sql)

# %%
# %%sql
# SELECT * FROM workspace.default.movies limit 10

# %%
df_sql.createOrReplaceTempView('temp_view')

# %%
# %%sql
# select * from temp_view limit 10
